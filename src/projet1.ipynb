# %%
data.pleasantness <- read.csv("~/Documents/ML/BIO322-Regression/data/training_data.csv")
head(data.pleasantness)
# Out:
#   Intensity VALENCE.PLEASANTNESS SWEETORSOUR complexity.from.pubmed MW
# 1 low       45                   FALSE       302.0                  208.33
# 2 high      49                    TRUE        72.6                  122.18
# 3 high      56                    TRUE       259.0                  242.29
# 4 high       7                   FALSE        56.6                   88.12
# 5 low       51                   FALSE        84.7                  136.21
# 6 high      21                   FALSE       160.0                  192.28
#   AMW   Sv     Se     Sp     Si     ... Psychotic.80 Psychotic.50 Hypertens.80
# 1 5.952 19.698 34.491 21.523 39.571 ... 0            0            1
# 2 6.431 11.349 18.745 12.261 21.285 ... 0            0            0
# 3 7.572 20.832 32.167 21.693 35.535 ... 0            0            1
# 4 6.294  7.537 14.189  7.955 16.080 ... 0            0            0
# 5 6.191 12.876 21.629 14.023 24.701 ... 0            0            0
# ...

# %%
set.seed(1)
idx.train <- sample(nrow(data.pleasantness), nrow(data.pleasantness)*3/4)
data.train <- data.pleasantness[idx.train,]
data.test <- data.pleasantness[-idx.train,]

# %%
lm.fit <- lm(data.train$VALENCE.PLEASANTNESS ~ ., data = data.train) 
summary(lm.fit)
# Out:
# Call:
# lm(formula = data.train$VALENCE.PLEASANTNESS ~ ., data = data.train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -37.654  -6.250   0.000   6.346  37.654
#
# Coefficients: (4556 not defined because of singularities)
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -6.016e+06  3.160e+06  -1.904  0.05830 .
# Intensitylow            3.692e+00  1.638e+00   2.254  0.02520 *
# SWEETORSOURTRUE         2.486e+01  2.614e+00   9.507  < 2e-16 ***
# complexity.from.pubmed  1.026e+01  2.170e+01   0.473  0.63684
# MW                      8.829e+02  2.042e+03   0.432  0.66592
# AMW                    -3.900e+02  2.979e+03  -0.131  0.89595
# Sv                      1.542e+05  1.935e+05   0.797  0.42651
# Se                     -4.071e+04  1.357e+05  -0.300  0.76442
# Sp                     -9.519e+04  8.907e+04  -1.069  0.28643
# Si                     -1.540e+05  7.851e+04  -1.961  0.05118 .
# ...
